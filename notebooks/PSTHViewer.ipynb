# %% [markdown]
# # PSTHViewer

# %%
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2

from ephys.src.utils.viz import PSTHViewer, PSTHWidget
from labdata.schema import SpikeSorting
from chipmunk import Chipmunk  # type: ignore

# %% [markdown]
# ### Check behavior metadata for sorted sessions

# %%
(Chipmunk()) & SpikeSorting().fetch("subject_name", "session_name", as_dict=True)

# %%
subject = "GRB058"
session = "20260224_152424"

viewer = PSTHViewer(
    subject=subject,
    session=session,
    unit_criteria_id=1,
    pre_seconds=0.1,
    post_seconds=0.15,
    binwidth_ms=10,
    plot_type="heatmap",  # "raster" | "heatmap" | "psth"
)

widget = PSTHWidget(viewer)
widget.show()

# %%
subject = "GRB059"
session = "20260225_154153"

viewer = PSTHViewer(
    subject=subject,
    session=session,
    unit_criteria_id=1,
    pre_seconds=0.1,
    post_seconds=0.15,
    binwidth_ms=10,
    plot_type="heatmap",  # "raster" | "heatmap" | "psth"
)

widget = PSTHWidget(viewer)
widget.show()

# %%
subject = "GRB060"
session = "20260225_162037"

viewer = PSTHViewer(
    subject=subject,
    session=session,
    unit_criteria_id=1,
    pre_seconds=0.1,
    post_seconds=0.15,
    binwidth_ms=10,
    plot_type="heatmap",  # "raster" | "heatmap" | "psth"
)

widget = PSTHWidget(viewer)
widget.show()

# %% [markdown]
# ### TODO:
# GRB006 will fail because the events are being handled through the obx logic in the script. I need to add something to fix that.

# %%
subject = "GRB006"
session = "20240821_121447"

viewer = PSTHViewer(
    subject=subject,
    session=session,
    unit_criteria_id=1,
    pre_seconds=0.1,
    post_seconds=0.15,
    binwidth_ms=10,
    plot_type="heatmap",  # "raster" | "heatmap" | "psth"
)

widget = PSTHWidget(viewer)
widget.show()
