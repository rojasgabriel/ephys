# %%
from labdata.schema import UnitCountCriteria

# %%
d = [
    {
        "unit_criteria_id": 0,
        "sua_criteria": "isi_contamination < 0.1 & amplitude_cutoff < 0.1 & spike_duration > 0.1 & spike_amplitude > 50 & presence_ratio > 0.6 & firing_rate > 1",
        "mua_criteria": None,
    },
    {
        "unit_criteria_id": 1,
        "sua_criteria": "isi_contamination < 0.1 & amplitude_cutoff < 0.1 & spike_duration > 0.1 & spike_amplitude > 50 & presence_ratio > 0.6 & firing_rate > 1 & depth_drift_range < 6",
        "mua_criteria": None,
    },
]
# TODO: the drift measurement is actually the start to end one. I have to delete all the UnitCount tables and reinsert the correct criteria
UnitCountCriteria().insert(d, skip_duplicates=True)
