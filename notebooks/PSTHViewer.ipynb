# %% [markdown]
# # PSTHViewer

# %%
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2

from ephys.src.utils.viz import PSTHViewer, PSTHWidget
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       2 get_ipython().run_line_magic('load_ext', 'autoreload')
#       3 get_ipython().run_line_magic('autoreload', '2')
# ----> 5 from ephys.src.utils.viz import PSTHViewer, PSTHWidget
#
# File ~/lib/ephys/src/utils/viz.py:13
#      11 import ipywidgets as widgets  # type: ignore
#      12 from IPython.display import display, clear_output
# ---> 13 from src.utils.utils_IO import fetch_good_units, fetch_session_events, fetch_trial_metadata
#      16 class PSTHViewer:
#      17     def __init__(
#      18         self,
#      19         subject: Optional[str] = None,
#    (...)     27         axes: Optional[Axes] = None,
#      28     ) -> None:
#
# ModuleNotFoundError: No module named 'src'

# %%
subject = "GRB058"
session = "20260224_152424"

viewer = PSTHViewer(
    subject=subject,
    session=session,
    unit_criteria_id=1,
    pre_seconds=0.1,
    post_seconds=0.15,
    binwidth_ms=10,
    plot_type="heatmap",  # "raster" | "heatmap" | "psth"
)

widget = PSTHWidget(viewer)
widget.show()

# %%
subject = "GRB059"
session = "20260225_154153"

viewer = PSTHViewer(
    subject=subject,
    session=session,
    unit_criteria_id=1,
    pre_seconds=0.1,
    post_seconds=0.15,
    binwidth_ms=10,
    plot_type="heatmap",  # "raster" | "heatmap" | "psth"
)

widget = PSTHWidget(viewer)
widget.show()

# %%
subject = "GRB060"
session = "20260225_162037"

viewer = PSTHViewer(
    subject=subject,
    session=session,
    unit_criteria_id=1,
    pre_seconds=0.1,
    post_seconds=0.15,
    binwidth_ms=10,
    plot_type="heatmap",  # "raster" | "heatmap" | "psth"
)

widget = PSTHWidget(viewer)
widget.show()

# %%
subject = "GRB006"
session = "20240821_121447"

viewer = PSTHViewer(
    subject=subject,
    session=session,
    unit_criteria_id=1,
    pre_seconds=0.1,
    post_seconds=0.15,
    binwidth_ms=10,
    plot_type="heatmap",  # "raster" | "heatmap" | "psth"
)

widget = PSTHWidget(viewer)
widget.show()
